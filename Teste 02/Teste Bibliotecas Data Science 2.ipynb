# %% [markdown]
# <h1> TESTE 02</h1>
# <h2> INTRODUÇÃO </h2>
# <p style="text-align:justify;text-justify:inter-word;">Nesse teste vamos escolher um dataset. Usar alguns classificadores. Alterar dados e parâmetros para melhorar a performance de classificação e, posteriormente, comparar as métricas.</p>
#
# <p style="text-align:justify;text-justify:inter-word;">O diagnóstico preciso das doenças eritema-escamosas é um problema real em dermatologia. Em geral, a análise clínica é insuficiente, tornando-se necessária a realização de uma biópsia. Porém, as doenças também possuem muitas características histopatológicas similares. Outra dificuldade para o diagnóstico diferencial é que uma doença pode apresentar as características de outra doença na fase inicial e pode ter os traços característicos nas fases seguintes (Demiroz G. et al., 1998). </p>
# <p style="text-align:justify;text-justify:inter-word;">O presente teste concentra-se no diagnóstico de 6 (seis) principais doenças eritema-escamosas (classes) que são :</p>
# <ul>
#     <li>Psoríase;</li>
#     <li>Dermatite crônica;</li>
#     <li>Dermatite seborreica;</li>
#     <li>Líquen plano;</li>
#     <li>Pitiríase rósea;</li>
#     <li>Pitiríase rubro pilar.</li>
# </ul>
#
# <p style="text-align:justify;text-justify:inter-word;"> O presente experimento tem como objetivo mostrar que é possível utilizar <strong><i>machine learning</i></strong> para auxiliar no diagnóstico das doenças supracitadas.</p>

# %% [markdown]
# <h2>METODLOGIA</h2>
# <p style="text-align:justify;text-justify:inter-word;">O experimento teste compreende o estudo das principais características das doenças eritêmo-escamosas para o entendimento da dificuldade de classificação. </p>
# <p style="text-align:justify;text-justify:inter-word;">Em um primeiro momento são realizadas algumas análises e, também tratamento dos dados, preparando-os para os experimentos (pré-processamento).São aplicadas técnicas estatísticas com o intuito de descobrir quais os atributos que melhor descrevem as classes. Nessa parte do experimento são gerados diversos <i>dataframes</i> com dados derivados do <i>datafarme</i> original com o intuito de tes.</p>
#
# <p style="text-align:justify;text-justify:inter-word;">Posteriormente, são realizados os experimentos de classificação com cada um dos <i>dataframes</i> gerados, com o intuito de comparar e identificar o melhor método de classificação e o melhor conjunto de dados.</p>

# %% [markdown]
# <h2>DOENÇAS ERITEMATO-ESCAMOSAS TRABALHADAS NO MODELO</h2>
# <p style="text-align:justify;text-justify:inter-word;">A <strong>psoríase</strong> (do grego psora "coçeira" + -sis "ação, condição") é uma doença crônica inflamatória comum, carcterizada por hiperproliferação da epiderme. Trata-se de doença incurável, caracterizada por períodos de remissões e exacerbações, cujo diagnóstico é fundamentalmente clínico. Esta doença pode causar desconforto físico e psíquico, implicando uma, série de restrições adaptativas.</p>
# <p style="text-align:justify;text-justify:inter-word;">Os aspectos clínicos da <strong>psoríase</strong> se manifestam, na maioria das vezes, por placas eritemato-escamosas, bem delimitadas, ocasionalmente pruriginosas, em áreas de traumas constantes na pele – cotovelos, joelhos, região pré-tibial, couro cabeludo e região sacra. O tamanho e o número das placas é variável e, toda a pele podendo ser afetada. Sintomas como prurido (coceira) e queimação podem estar presentes de forma geral em grau leve.</p>
# <p style="text-align:center;text-justify:inter-word;"><img src="./psoríase.png" alt="psoríase"><strong><i>Figura 1 - Psoríase.</i></strong></p>
# <p style="text-align:justify;text-justify:inter-word;">A <strong>dermatite crônica</strong>, também conhecida por <strong>dermatite de contato</strong> (<strong>eczema por irritante primário</strong> ou <strong>eczema alérgico</strong>), é uma reação inflamatória que ocorre devido ao contato da pele com um agente irritativo ou que cause alergia. O eczema por irritante primário ocorre pela ação direta da substância sobre a pele, que a danifica e desencadeia a reação.</p>
# <p style="text-align:center;text-justify:inter-word;"><img src="./dermatite crônica.png" alt="psoríase"><strong><i>Figura 2 - Dermatite Crônica.</i></strong></p>
# <p style="text-align:justify;text-justify:inter-word;">As características típicas do <strong>eczema de contato</strong> na fase aguda são a vermelhidão, inchaço, formação de vesículas (pequenas bolhas), bolhas e secreção. Mais tarde ocorre a formação de placas e descamação (fase sub-aguda). Em uma fase mais tardia, quando se torna crônico, aparece a liquenificação (espessamento da pele). O prurido (coceira) está presente em todas as fases, e pode ser discreto ou muito intenso.
# <p style="text-align:justify;text-justify:inter-word;">A <strong>dermatite seborreica (DS)</strong> é uma doença inflamatória crônica comum, que acomete cerca de 1 a 3% da população geral dos EUA, sendo 3 a 5% em adultos jovens. Possui dois picos de incidência: um no recém-nascido, até os três meses de vida, e outro na fase adulta, aproximadamente entre os 30 e 60 anos de idade. A apresentação bimodal da doença (ao nascimento e pós-puberal) sugere que ela esteja relacionada a hormônios sexuais. Os homens são acometidos com maior frequência em todas as faixas etárias e não há predileção racial.</p>
# <p style="text-align:center;text-justify:inter-word;"><img src="./dermatite seborreica.png" alt="psoríase"><strong><i>Figura 3 - Dermatite Seborreica.</i></strong></p>
# <p style="text-align:justify;text-justify:inter-word;">A histopatologia da <strong>dermatite seborreica</strong> depende do estágio clínico em que se encontra. A <strong>DS</strong> do adulto é uma dermatite crônica, de curso recidivante, que varia desde um eritema leve a moderado até lesões papulosas, exsudativas e/ou escamativas, com períodos de exacerbação relacionados ao estresse ou privação de sono.</p>
# <p style="text-align:justify;text-justify:inter-word;"><strong>Líquen plano</strong> (Lichen planus) é doença inflamatória crônica com acometimento cutaneomucoso relativamente comum, descrita pela primeira vez em 1869, por Erasmus Wilson, que pode envolver pele/anexos e mucosas, separadamente ou simultaneamente. Na cavidade oral este comprometimento pode acontecer isoladamente ou com comprometimento cutâneo concomitante. Com relação aos aspectos clínicos, destaca-se maior variabilidade das lesões cutâneas quando em comparação com as lesões orais, as quais aparentam evolução prolongada, podendo persistir por anos. Os aspectos microscópicos no líquen plano cutâneo são considerados, por vários autores, característicos e suficientes para estabelecer, na grande maioria dos casos, o diagnóstico histopatológico desta doença na pele.</p>
# <p style="text-align:center;text-justify:inter-word;"><img src="./líquen plano.png" alt="psoríase"><strong><i>Figura 4 - Líquen Plano.</i></strong></p>
# <p style="text-align:justify;text-justify:inter-word;">A <strong>pitiríase rósea (PR)</strong> é dermatose aguda e inflamatória de origem ainda não completamente elucidada. Há alguns elementos de sua epidemiologia e imunologia que sugerem a possibilidade que possa se desencadear graças a agentes infecciosos (mais suspeita é a origem viral). Há ainda a possibilidade de aparecer após o uso de algumas vacinas (BCG, HPV e difteria), bem como de medicações (ácido acetilsalicílico, barbitúricos, bismuto, captopril, clonidina, ouro, imatinib, isotretinoína, cetotifeno, levamisol, metronidazol, omeprazol, D-peniclamina e terbinafina, entre outras). Casos atípicos são comuns ecolocam à prova a experiência e a perspicácia clínica do médico. Entre as variantes clínicas, as lesões purpúricas raramente têm sido descritas.</p>
# <p style="text-align:center;text-justify:inter-word;"><img src="./pitiríase rósea.png" alt="psoríase"><strong><i>Figura 5 - Pitiríase Rósea.</i></strong></p>
# <p style="text-align:justify;text-justify:inter-word;">Clinicamente a <strong>PR</strong> é caracterizada por curso evolutivo tipicamente autolimitado de lesões peculiares em placa, de forma arredondada ou ovalada, eritêmato- pápulo-escamosas, distribuídas no tronco e em extremidades; entretanto, diversas variantes atípicas da doença têm sido registradas.</p>
# <p style="text-align:justify;text-justify:inter-word;"><strong>Pitiríase rubro pilar</strong> apresenta duas formas clínicas: uma familiar de início em geral na infância e outra adquirida que ocorre em adultos sem qualquer antecedente familiar. A etiologia é desconhecida; a predisposição a esta doença é usualmente transmitida como herança autossômica dominante. Acomete ambos os sexos com igual frequência. As lesões iniciais são pápulas foliculares eritematosas que coalescem formando placas eritemato-escamosas. A erupção inicia-se, geralmente, pelo couro cabeludo e estende-se para a face, nuca, tronco e extremidades, podendo generalizar-se. É patognomônica a presença de pápulas foliculares, com espículas córneas, localizadas no dorso da primeira e segunda falange dos dedos. Pode ocorrer, também, queratoderma palmo-plantar. Prurido é discreto e eventual. Não há comprometimento sistêmico.</p>
# <p style="text-align:center;text-justify:inter-word;"><img src="./pitiríase rubro pilar.png" alt="psoríase"><strong><i>Figura 6 - Pitiríase Rubro Pilar.</i></strong></p>

# %% [markdown]
# <h2>O DATASET</h2>
# <p style="text-align:justify;text-justify:inter-word;"> O <i>dataset</i> utilizado para esse experimento pode ser encontrado no repositório da Universidade da California em Irvine (UCI) e pode ser acessado a partir do link: <a href="http://archive.ics.uci.edu/ml/datasets/Dermatology">UCI - Machine Learning Repository</a>.</p>
#
# <p><strong>Número de instâncias (observações):</strong> 366</p>
#
# <p><strong>Número de atributos:</strong> 34</p>

# %% [markdown]
# <h3>INFORMAÇÃO DOS ATRIBUTOS</h3>
# <p>Nas tabelas abaixo os índices são apresentados iniciando a partir do zero (diferentemente do que está no arquivo). Isso se dá para auxiliar na programação em Python, cujos índices iniciam, também, em zero.

# %% [markdown]
# <h4>ATRIBUTOS CLÍNICOS (usa 0, 1, 2, 3, a menos que outro seja indicado)</h4>

# %% [markdown]
# <table align='left' style='border-top:solid 1px #000; border-bottom:solid 1px #000; padding:5px;'>
#     <tr style='border-bottom:solid 1px #000;'>
#         <td style='text-align:center;'><strong>ÍNDICE</strong></td>
#         <td style='text-align:left;'><strong>ATRIBUTO</strong></td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>0</td>
#         <td style='text-align:left;'>Eritema</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>1</td>
#         <td style='text-align:left;'>Escamação</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>2</td>
#         <td style='text-align:left;'>Bordas definidas</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>3</td>
#         <td style='text-align:left;'>Prurido</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>4</td>
#         <td style='text-align:left;'>Fenômeno de Koebner</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>5</td>
#         <td style='text-align:left;'>Pápulas poligonais</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>6</td>
#         <td style='text-align:left;'>Pápulas foliculares</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>7</td>
#         <td style='text-align:left;'>Acometimento da mucosa oral</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>8</td>
#         <td style='text-align:left;'>Acometimento do joelho e cotovelo</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>9</td>
#         <td style='text-align:left;'>Acometimento do couro cabeludo</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>10</td>
#         <td style='text-align:left;'>Histórico familiar (0-não ou 1-sim)</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>33</td>
#         <td style='text-align:left;'>Idade (linear)</td>
#     </tr>
# </table>

# %% [markdown]
# <div style="color: rgb(255,255,255); background-color: rgb(150,0,0); width: 700px; height: 50px; text-align: Justify; padding: 10px;">
#     <p><strong>*** NOTA:</strong> Valores ausentes no atributo <strong>Idade</strong> cujos registros foram destacados com um '?' (ponto de interrogação).</p>
# </div>

# %% [markdown]
# <h4>ATRIBUTOS HISTOPATOLÓGICOS (usa 0, 1, 2, 3, a menos que outro seja indicado)</h4>

# %% [markdown]
# <table align='left' style='border-top:solid 1px #000; border-bottom:solid 1px #000; padding:5px;'>
#     <tr style='border-bottom:solid 1px #000;'>
#         <td style='text-align:center;'><strong>ÍNDICE</strong></td>
#         <td style='text-align:left;'><strong>ATRIBUTO</strong></td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>11</td>
#         <td style='text-align:left;'>Incontinência de melanina</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>12</td>
#         <td style='text-align:left;'>Infiltrado eosinofílico</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>13</td>
#         <td style='text-align:left;'>Infiltrado de polimorfonucleares</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>14</td>
#         <td style='text-align:left;'>Fibrose da derme papilar</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>15</td>
#         <td style='text-align:left;'>Exocitose</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>16</td>
#         <td style='text-align:left;'>Acantose</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>17</td>
#         <td style='text-align:left;'>Hiperceratose</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>18</td>
#         <td style='text-align:left;'>Paraceratose</td>
#     </tr>
#      <tr>
#         <td style='text-align:center;'>19</td>
#         <td style='text-align:left;'>Baqueteamento das cristas epiteliais</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>20</td>
#         <td style='text-align:left;'>Alongamento das cristas epiteliais</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>21</td>
#         <td style='text-align:left;'>Afinamento da epiderme suprapapilar</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>22</td>
#         <td style='text-align:left;'>Pústula espongiforme</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>23</td>
#         <td style='text-align:left;'>Microabscesso de Munro</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>24</td>
#         <td style='text-align:left;'>Hipergranulose focal</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>25</td>
#         <td style='text-align:left;'>Agranulose</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>26</td>
#         <td style='text-align:left;'>Vacuolização e dano da camada basal</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>27</td>
#         <td style='text-align:left;'>Espongiose</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>28</td>
#         <td style='text-align:left;'>Aparência de dente de serra</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>29</td>
#         <td style='text-align:left;'>Tampão córneo</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>30</td>
#         <td style='text-align:left;'>Paraceratose perifolicular</td>
#     </tr>
#      <tr>
#         <td style='text-align:center;'>31</td>
#         <td style='text-align:left;'>Infiltrado inflamatório mononuclear</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>32</td>
#         <td style='text-align:left;'>Faixa de infiltrado</td>
#     </tr>
# </table>

# %% [markdown]
# <h4>DISTRIBUIÇÃO DAS CLASSES</h4>

# %% [markdown]
# <p>Vale observar que o número à esquerda é o código da classe e não um índice.</p>
# <table align='left' style='border-top:solid 1px #000; border-bottom:solid 1px #000; padding:5px;'>
#     <tr style='border-bottom:solid 1px #000;'>
#         <td style='text-align:center;'><strong>CÓDIGO</strong></td>
#         <td style='text-align:left;'><strong>CLASSE</strong></td>
#          <td style='text-align:left;'><strong>CASOS</strong></td>
#     </tr>
#      <tr>
#         <td style='text-align:center;'>1</td>
#         <td style='text-align:left;'>Psoríase</td>
#          <td style='text-align:rigth;'>112</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>2</td>
#         <td style='text-align:left;'>Dermatite seborreica</td>
#          <td style='text-align:rigth;'>61</td>
#     </tr>
#      <tr>
#         <td style='text-align:center;'>3</td>
#         <td style='text-align:left;'>Liquén plano</td>
#          <td style='text-align:rigth;'>72</td>
#     </tr>
#      <tr>
#         <td style='text-align:center;'>4</td>
#         <td style='text-align:left;'>Pitiríase rósea</td>
#          <td style='text-align:rigth;'>49</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'>5</td>
#         <td style='text-align:left;'>Dermatite crônica</td>
#          <td style='text-align:rigth;'>52</td>
#     </tr>
#     <tr>
#         <td style='text-align:center;'><strong>6</strong></td>
#         <td style='text-align:left;'>Pitiríase rubro pilar</td>
#          <td style='text-align:rigth;'>20</td>
#     </tr>
# </table>

# %% [markdown]
# <h2>ANÁLISE E PREPARAÇÃO DOS DADOS</h2>
# <p style="text-align:justify;text-justify:inter-word">Carregando as bibliotecas utilizadas.</p>
# <ul style="text-align:justify;text-justify:inter-word;">
#     <li>Pandas</li>
#     <li>Numpy</li>
#     <li>Matplotlib</li>
#     <li>SeaBorn</li>
# </ul>

# %%
##carregando as bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %% [markdown]
# <h3>CARREGANO O DATASET</h3>

# %%
## importando dados do dataset para um dataframe 
df = pd.read_csv("dermatology_v2.csv")

# %% [markdown]
# <h3>VISUALIZANDO OS DADOS</h3>

# %%
## visualizando o cabeçalho as colunas (nomes dos atributos)
df.columns
# Out:
# Index(['erythema', 'scaling', 'definite borders', 'itching',
#        'koebner phenomenon', 'polygonal papules', 'follicular papules',
#        'oral mucosal involvement', 'knee and elbow involvement',
#        'scalp involvement', 'family history', 'melanin incontinence',
#        'eosinophils in the infiltrate', 'PNL infiltrate',
#        'fibrosis of the papillary dermis', 'exocytosis', 'acanthosis',
#        'hyperkeratosis', 'parakeratosis', 'clubbing of the rete ridges',
#        'elongation of the rete ridges',
#        'thinning of the suprapapillary epidermis', 'spongiform pustule',
#        'munro microabcess', 'focal hypergranulosis',
#        'disappearance of the granular layer',
#        'vacuolisation and damage of basal layer', 'spongiosis',
#        'saw-tooth appearance of retes', 'follicular horn plug',
#        'perifollicular parakeratosis', 'inflammatory monoluclear inflitrate',
#        'band-like infiltrate', 'age', 'target'],
#       dtype='object')

# %%
## visualizando os dados do dataset
df
# Out:
#      erythema  scaling  definite borders  itching  koebner phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal papules  follicular papules  oral mucosal involvement  \
# ...

# %% [markdown]
# <h3>ANÁLISE PRELIMINAR</h3>

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">Verificou-se a necessidade de alterações nos valores contidos no <i><strong>dataset</strong></i> o intuito de retirar os valores 0 (zero), para não comprometer o possível uso de uma rede neural (atributos com valores zero na entrada zera um neurônio). Desta forma, para os valores dos atributos clínicos e histopatológicos cuja a intensidade variavam de 0 (nenhuma intensidade) a 3(intenso) são adotados os valores 1,2,3 e 4 em substituição, também representando a intensidade. No atributo histórico familiar, que contém os valores 0 (zero) e 1(um) significando não e sim respectivamente, altera-se de 0 para  -1 (menos um), configurando o "não" e mantém o 1(um) para o "sim".</p>
# <p style="text-align:justify;text-justify:inter-word;">Nas instruções do <strong><i>dataset</i></strong> há uma observação sobre a idade ter valores que não foram especificados e foram substituídos por "?". Para não perder esses registros inteiros optou-se, primeiramente, por substituir o "?" pela média.</p>

# %% [markdown]
# <h3>ALTERANDO OS DADOS</h3>

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">Criando funções para as alterações necessárias nos atributos.</p>

# %%
## funções lambda 
define_atributo = lambda x: x+1
define_historico = lambda x: x.replace(0,2) #1 verdadeiro 2 falso
define_idade = lambda x,valor_1,valor_2: x.replace(valor_1,valor_2)
##outra função para converter idade para valor discreto
#regra: abaixo da média = 1 acima = 2
def idade_discreta (x):
    if x <= 20:
        return 1
    elif (x > 20 and x <= 40):
        return 2
    elif (x > 40 and x <= 60):
        return 3
    elif (x > 60):
        return 4

# %% [markdown]
# <p>Alterando os <strong>atributos clínicos</strong>:</p>

# %%
for i in range(0,10):
    ## mostrando quais atributos a serem alterados
    print(df.columns[i])
    
    ## alterando os atributos
    df[df.columns[i]] = define_atributo(df[df.columns[i]])
# Out:
# erythema
# scaling
# definite borders
# itching
# koebner phenomenon
# polygonal papules
# follicular papules
# oral mucosal involvement
# knee and elbow involvement
# scalp involvement

# %%
## alterando histórico familiar
df['family history'] = define_historico(df['family history'])

# %%
df['family history']
# Out:
# 0      2
# 1      1
# 2      2
# 3      2
# 4      2
#       ..
# 361    2
# 362    2
# 363    2
# 364    2
# 365    2
# Name: family history, Length: 366, dtype: int64

# %%
## tratando a idade
# como não tem como calcular a média com um literal no meio, substitui-se o 
# literal '?' por '0'.
df['age'] = define_idade(df['age'],'?','0')

# %%
# converte-se a coluna para numérico, pois ela está como literal
df['age'] = pd.to_numeric(df['age'])

# %%
# visualizando o histograma do atributo 'age' (idade)
sb.distplot(df['age'])

# %%
## Contando quantos elementos zeros existem
cont=0
for i in df['age']:
    if (df['age'].values[i]==0):
       cont+=1
result = (366-cont)

# calcula-se a média e substitui os zeros pela média
media1 = int(df['age'].mean()) #média contando com os indivíduos com idade zero (não serve)
media2 = int(df['age'].sum() / result )#média sem os indivíduos com idade zero (ok)
print('Média com indivíduos: ' ,media1, ' Média sem os indivíduos: ',media2 )
#adotamos a média de 41 anos
# Out:
# Média com indivíduos:  35  Média sem os indivíduos:  41

# %%
## alterando a idade de zero para a média (analisando ambas)
df['age'] = define_idade(df['age'],0,media2)
##conferindo a alteração
df
# Out:
#      erythema  scaling  definite borders  itching  koebner phenomenon  \
# 0           3        3                 1        4                   1
# 1           4        4                 4        3                   2
# 2           3        2                 3        4                   2
# 3           3        3                 3        1                   1
# 4           3        4                 3        3                   3
# ..        ...      ...               ...      ...                 ...
# 361         3        2                 2        1                   2
# 362         4        3                 2        1                   2
# 363         4        3                 3        3                   4
# 364         3        2                 4        2                   3
# 365         4        3                 3        1                   1
#
#      polygonal papules  follicular papules  oral mucosal involvement  \
# ...

# %%
##Para não ver a linha do KDE no gráfico use o parâmetro 'kde' igual a 'False',
## que por padrão é igual a 'True' 
##sb.distplot(df['age'], kde=False)
# visualizando o histograma do atributo 'age' (idade)
sb.distplot(df['age'])

# %% [markdown]
# <p>A discretização da variável idade segue o índice da lista abaixo, conforme as regras:</p>
# <ol>
#     <li>se a idade for menor ou igual a 20 anos</li>
#     <li>se a idade estiver entre 21 e 40 anos</li>
#     <li>se a idade estiver entre 41 e 60 anos</li>
#     <li>se a idade for maior ou igual a 61 anos</li>
# </ol>

# %%
## Realizando a discretização do dado de idade seguindo a seguinte regra:
for i in range(0,366):
    df['age'].values[i] = idade_discreta(df['age'].values[i])
##  print (df['age'].values[i]) 
## conferindo a alteração
#df['age']"""

# %% [markdown]
# <p>Conferindo a alteração dos atributos clínicos:</p>

# %%
df
# Out:
#      erythema  scaling  definite borders  itching  koebner phenomenon  \
# 0           3        3                 1        4                   1
# 1           4        4                 4        3                   2
# 2           3        2                 3        4                   2
# 3           3        3                 3        1                   1
# 4           3        4                 3        3                   3
# ..        ...      ...               ...      ...                 ...
# 361         3        2                 2        1                   2
# 362         4        3                 2        1                   2
# 363         4        3                 3        3                   4
# 364         3        2                 4        2                   3
# 365         4        3                 3        1                   1
#
#      polygonal papules  follicular papules  oral mucosal involvement  \
# ...

# %%
##Criando um dataframe com os dados clínicos
#para fazer as análises em separado tb
att_sel =list(df.columns[range(0,11)])
att_sel.insert(11,'age')
att_sel.insert(12,'target')
df_clinico = df[att_sel]
df_clinico
# Out:
#      erythema  scaling  definite borders  itching  koebner phenomenon  \
# 0           3        3                 1        4                   1
# 1           4        4                 4        3                   2
# 2           3        2                 3        4                   2
# 3           3        3                 3        1                   1
# 4           3        4                 3        3                   3
# ..        ...      ...               ...      ...                 ...
# 361         3        2                 2        1                   2
# 362         4        3                 2        1                   2
# 363         4        3                 3        3                   4
# 364         3        2                 4        2                   3
# 365         4        3                 3        1                   1
#
#      polygonal papules  follicular papules  oral mucosal involvement  \
# ...

# %% [markdown]
# <p>Tratando os <strong>atributos histopatológicos</strong>:</p>

# %%
##alterando os dados histopatológicos
for i in range(11,33):
    ## mostrando quais atributos serão alterados
    print(df.columns[i])
    ## alterando os atributos
    df[df.columns[i]] = define_atributo(df[df.columns[i]])
# Out:
# melanin incontinence
# eosinophils in the infiltrate
# PNL infiltrate
# fibrosis of the papillary dermis
# exocytosis
# acanthosis
# hyperkeratosis
# parakeratosis
# clubbing of the rete ridges
# elongation of the rete ridges
# thinning of the suprapapillary epidermis
# spongiform pustule
# munro microabcess
# focal hypergranulosis
# disappearance of the granular layer
# vacuolisation and damage of basal layer
# spongiosis
# saw-tooth appearance of retes
# follicular horn plug
# perifollicular parakeratosis
# inflammatory monoluclear inflitrate
# band-like infiltrate

# %% [markdown]
# <p>Conferindo a alteração dos <strong>atributos histopatológicos</strong>:</p>

# %%
## mostrando o dataframe
df

# %%
#gravando o conjunto de dados já tratado
df.to_csv('dermatology_completo_tratado.csv')

# %%
##Criando um dataframe com os dados histopatológicos
#para fazer as análises em separado tb
att_sel =list(df.columns[range(11,33)])
att_sel.insert(23,'target')
df_histopatologico = df[att_sel]
df_histopatologico
# Out:
#      melanin incontinence  eosinophils in the infiltrate  PNL infiltrate  \
# 0                       1                              1               1
# 1                       1                              1               2
# 2                       2                              1               1
# 3                       1                              1               4
# 4                       2                              1               1
# ..                    ...                            ...             ...
# 361                     1                              1               2
# 362                     1                              1               1
# 363                     3                              3               1
# 364                     3                              1               1
# 365                     1                              1               2
#
#      fibrosis of the papillary dermis  exocytosis  acanthosis  hyperkeratosis  \
# ...

# %%
## importando a funções do sklearn 
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression, SelectKBest, SelectPercentile
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler, Normalizer

# %%
## Vamos amostrar rapidamente um conjunto de treinamento, 
## mantendo 40% dos dados para testar (avaliar) o classificador (validação cruzada)
## dessa vez diretamente do dataframe
X_train, X_test, y_train, y_test = train_test_split(df.drop(['target'],axis=1),df['target'], test_size=0.4, random_state=0)
## mostrando os conjuntos de treinamento e teste
print('Dados de Treino {}'.format(X_train.shape))
print('Target de Treino {}'.format(y_train.shape))
print("Dados de Teste {}".format(X_test.shape))
print('Target de Teste {}'.format(y_test.shape))
# Out:
# Dados de Treino (219, 34)
# Target de Treino (219,)
# Dados de Teste (147, 34)
# Target de Teste (147,)

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">Agora que os dados brutos receberam tratamento prévio, torna-se essencial entender a necessidade de seleção de variáveis.</p>

# %% [markdown]
# <h3>CONSIDERAÇÕES IMPORTANTES SOBRE A SELEÇÃO DE VARIÁVEIS</h3>
#
# <p style="text-align:justify;text-justify:inter-word;">A seleção de variáveis é um processo importante no fluxo de trabalho de um cientista de dados. Em casos como este que apresenta dados com altíssima dimensionalidade (quantidade excessiva de colunas), os modelos de classificação geralmente se mostram lentos porque o tempo de treinamento aumenta exponencialmente com o número de atributos de entrada.</p>
# <p style="text-align:justify;text-justify:inter-word;">Portanto é necessário selecionar os dados de entrada que mais contribuem para a saída de interesse do modelo. Isso se dá pelo risco crescente de <i>overfitting</i> em modelos com muitas variáveis, perdendo a eficácia ao tentar aplicar o modelo a novos dados.</p>

# %% [markdown]
# <div style="color: rgb(255,255,255); background-color: rgb(150,0,0); width: 700px; height: 140px; text-align: Justify; padding: 10px;">
#     <br><strong>*** NOTA:</strong> <i>Overfitting</i> (sobreajuste) é um termo usado em estatística para descrever quando um modelo estatístico se ajusta muito bem ao conjunto de dados anteriormente observado, mas se mostra ineficaz para prever novos resultados. É comum que a amostra apresente desvios causados por erros de medição ou fatores aleatórios.
# </div>

# %% [markdown]
# <h3>MÉTODOS PARA VERIFICAR A RELAÇÃO ENTRE VARIÁVEIS</h3>
#
# <p style="text-align:justify;text-justify:inter-word;">O presente estudo apresenta 34 variáveis de entrada para conseguir identificar as classes. Porém, conforme já explicado, isso pode prejudicar o experimento. Torna-se necessário utilizar de alguns critérios para selecionar os atributos vão dar melhor resposta ao experimento. Para isso vamos usar algumas técnicas estatísticas.</p>
#
# <h4>INFORMAÇÃO MÚTUA (MUTUAL INFORMATION)</h4>
# <p style="text-align:justify;text-justify:inter-word;">Informação mútua (em inglês mutual information) de duas variáveis aleatórias é a medida da dependência mútua entre as duas variáveis. Mais especificamente, a informação mútua quantifica a informação que uma variável aleatória contém acerca da outra. O conceito de informação mútua esta intrinsicamente ligado ao da Entropia de uma variável aleatória, uma noção fundamental da teoria da informação, que define a "quantidade de informação" contida em uma variável aleatória.</p>
#
# <p style="text-align:justify;text-justify:inter-word;">Não sendo limitado a variáveis aleatória com valores reais como o coeficiente de correlação, a MI é mais genérica e determina quão similar a distribuição conjunta p(X,Y) está dos produtos das distribuições marginais p(X)p(Y). MI é o valor esperado da pointwise mutual information (PMI).</p>
#
#
# <p style="text-align:justify;text-justify:inter-word;">Se X e y são indepedentes nenhuma informação sobre y pode ser obtida conhecendo X ou vice versa. Portanto, sua informação mútua é zero.</p>
# <p style="text-align:justify;text-justify:inter-word;">Se X é uma função determinística de y então pode-se determinar X de y e y de X com informação mútua 1.</p>

# %%
## Importando da biblioteca para mostrar as equações
from IPython.display import display, Math, Latex
#######################################################################################################################
## esse código LaTex é apenas para escrever a fórmula direitinho para vocês
print('Fórmula: ')
display(Math(r'MI (X;Y) = $$\sum_{\forall x \in X}$$ $$\sum_{\forall y \in Y}$$ p(x,y) log \frac{p(x,y)}{p(x)p(y)}'))
#######################################################################################################################
# Out:
# Fórmula:
# $\displaystyle MI (X;Y) = $$\sum_{\forall x \in X}$$ $$\sum_{\forall y \in Y}$$ p(x,y) log \frac{p(x,y)}{p(x)p(y)}$

# %% [markdown]
# <div style="color: rgb(255,255,255); background-color: rgb(150,0,0); width: 700px; height: 75px; text-align: Justify; padding: 10px;">
#     <br><strong>*** NOTA:</strong> Quanto menor o valor, menos a variável descreve a relação com o <i>target</i>.
# </div>

# %%
## a função mutual_info_classif realiza a operação descrita pela equação acima 
## e retorna esse conjunto de valores abaixo
mi = mutual_info_classif(X_train.fillna(0), y_train)
mi
# Out:
# array([0.10553577, 0.145962  , 0.18790417, 0.16578467, 0.32984618,
#        0.46920572, 0.08281407, 0.37703579, 0.44036866, 0.30182711,
#        0.08040782, 0.49207597, 0.09360354, 0.3929047 , 0.36829886,
#        0.48716003, 0.14775595, 0.09057628, 0.2519633 , 0.63299954,
#        0.57348656, 0.54442166, 0.13668059, 0.34171702, 0.43271979,
#        0.31414707, 0.41012936, 0.30314842, 0.44708701, 0.10385204,
#        0.13201271, 0.10744942, 0.49015469, 0.06117922])

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">A função <strong><i> mutual_info_classif</i></strong> estima informações mútuas para uma variável de destino discreta. A informação mútua (MI) entre duas variáveis aleatórias é um valor não negativo, que mede a dependência entre as variáveis. É igual a zero se e somente se duas variáveis aleatórias são independentes, e valores mais altos significam maior dependência.</p>
#
# <p style="text-align:justify;text-justify:inter-word;">A função baseia-se em métodos não paramétricos baseados na estimativa de entropia a partir de k-distâncias de vizinhos mais próximos. </p>
#
# <p style="text-align:justify;text-justify:inter-word;">Os números apresentam o fator de relação entre as variáveis e target, porém a visualização pode ser melhorada por um gráfico de barras no Pandas.</p>

# %%
mi = pd.Series(mi)
mi.index = X_train.columns
mi = mi.sort_values(ascending = False)
mi.plot.bar(figsize=(15,7))

# %% [markdown]
# <h4>SELECIONANDO OS MELHORES ATRIBUTOS</h4>
#
# <p style="text-align:justify;text-justify:inter-word;">Geralmente utiliza-se a seleção de 10 ou 20 melhores atributos para descrever o <strong><i>target</i></strong> (dependendo do tamanho do conjunto de dados).</p>
# <p style="text-align:justify;text-justify:inter-word;">A combinação de <strong><i>SelectKBest</i></strong> e <strong><i>SelectPercentile</i></strong> costuma ser uma boa opção!</p>
# <p style="text-align:justify;text-justify:inter-word;"><strong>Exemplo de seleção dos dez melhores atributos:</strong></p>
#
#
# <p style="text-align:justify;text-justify:inter-word;">O código usando a classe <strong><i>SelectKBest</i></strong> da biblioteca <strong><i>feature_selection</i></strong> combinada com o método de máximo coeficiente de informações para selecionar recursos pode ser visto a seguir:</p>

# %%
sel_ = SelectKBest(mutual_info_classif, k=10).fit(X_train.fillna(0), y_train)
att_sel = list(X_train.columns[sel_.get_support()])
att_sel
# Out:
# ['polygonal papules',
#  'melanin incontinence',
#  'exocytosis',
#  'clubbing of the rete ridges',
#  'elongation of the rete ridges',
#  'thinning of the suprapapillary epidermis',
#  'focal hypergranulosis',
#  'vacuolisation and damage of basal layer',
#  'saw-tooth appearance of retes',
#  'band-like infiltrate']

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">Pegando os dados cujos atributos foram selecionados como importantes diretamente do <strong><i>dataframe</i></strong> original e, também, o <i>target</i>, com o objetivo de montar um novo <strong><i>dataframe</i></strong>.</p>

# %%
att_sel.insert(10,'target')
att_sel
# Out:
# ['polygonal papules',
#  'melanin incontinence',
#  'exocytosis',
#  'clubbing of the rete ridges',
#  'elongation of the rete ridges',
#  'thinning of the suprapapillary epidermis',
#  'focal hypergranulosis',
#  'vacuolisation and damage of basal layer',
#  'saw-tooth appearance of retes',
#  'band-like infiltrate',
#  'target']

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">Cria-se um segundo <strong><i>dataframe</i></strong> com base nos 10 atributos mais importantes. Dessa forma, pode-se trabalhar e continuar com os testes nos dois <strong><i>dataframes</i></strong>.</p>

# %%
##criando o segundo dataframe com os 10 atributos "mais fortes" na classificação
df_10_best = df[att_sel]
df_10_best
# Out:
#      polygonal papules  melanin incontinence  exocytosis  \
# 0                    1                     1           4
# 1                    1                     1           2
# 2                    4                     2           2
# 3                    1                     1           1
# 4                    3                     2           2
# ..                 ...                   ...         ...
# 361                  1                     1           2
# 362                  1                     1           3
# 363                  3                     3           4
# 364                  4                     3           4
# 365                  1                     1           1
#
#      clubbing of the rete ridges  elongation of the rete ridges  \
# 0                              1                              1
# 1                              3                              3
# 2                              1                              1
# ...

# %%
#gravando o conjunto de dados já tratado
df_10_best.to_csv('dermatology_10_best.csv')

# %% [markdown]
# <h4>TESTE QUI-QUADRADO (FISHER SCORE - CHI-SQUARE)</h4>
#
# <p style="text-align:justify;text-justify:inter-word;"> A distribuição <strong><i>X <sup>2</sup></i></strong> ou <strong><i>qui-quadrado</i></strong> é uma das distribuições mais utilizadas em estatística inferencial, principalmente para realizar testes para avaliar quantitativamente a relação entre o resultado de um experimento e a distribuição esperada para o fenômeno. Em outras palavras, é utilizado para determinar se existe uma diferença significativa entre as frequências esperadas e as frequências observadas em uma ou mais categorias.</p>
# <p style="text-align:justify;text-justify:inter-word;">Dado um experimento onde foram realizadas N medidas de uma variável aleatória X. Em cada medida, a variável <i>X</i> assume os valores <i>x<sub>1</sub>, x<sub>2</sub>, ...,x<sub>n</sub></i>. Gostaríamos de testar se a distribuição experimental dos valores <i>x<sub>1</sub>, x<sub>2</sub>, ..., x<sub>k</sub>, ..., x<sub>n</sub></i> é consistente com a distribuição esperada para o fenômeno, <i>f(X)</i>. Em outras palavras, temos que avaliar como esperaríamos que as <i>n</i> medidas estivessem distribuídas e então comparar com a distribuição observada. Primeiramente, em geral <i>x</i> é uma variável contínua, de forma que não podemos nos referir ao valor esperado de medidas com um único valor de <i>x</i> (se <i>x</i> for contínuo, a probabilidade de <i>X</i> assumir um exato valor é zero). Logo, precisamos definir intervalos <i>a ≤ x ≤ b</i> e calcular o número esperado de medidas que devem estar dentro de cada intervalo <i>j</i>, em que <i>j = 1, 2, …, n</i> e <i>n</i> é o número de intervalos definidos. O número de medidas esperadas para o intervalo <i>j</i>, <i>Ex<sub>j</sub></i>, será, então:</p>

# %%
#######################################################################################################################
## esse código LaTex é apenas para escrever a fórmula direitinho para vocês
print('Fórmula: ')
display(Math(r'$E_j$ = n$Pr_j$'))
#######################################################################################################################
# Out:
# Fórmula:
# $\displaystyle E_j$ = n$Pr_j$

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">onde <i>Prj</i> é a probabilidade de <i>X</i> assumir um valor dentro do intervalo <i>j</i>. Essa probabilidade obviamente depende da distribuição <i>f(X)</i> e é normalizada:</p>

# %%
#######################################################################################################################
## esse código LaTex é apenas para escrever a fórmula direitinho para vocês
print('Fórmula: ')
display(Math(r'$$\sum_{j}$ n$Pr_j$$ = 1'))
#######################################################################################################################
# Out:
# Fórmula:
# $\displaystyle \sum_{j}$ n$Pr_j$$ = 1$

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">É natural analisar a diferença entre o número de amostras observadas dentro de cada intervalo, <i>O<sub>j</sub></i>, e o número esperado:</p>

# %%
#######################################################################################################################
## esse código LaTex é apenas para escrever a fórmula direitinho para vocês
print('Fórmula: ')
display(Math(r'$O_j$ - $E_j$'))
#######################################################################################################################
# Out:
# Fórmula:
# $\displaystyle O_j$ - $E_j$

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">de forma que quanto menor forem estes valores, melhores serão as chances de nossa hipótese para <i>f(X)</i> ser verdadeira. Porém, não podemos esperar que os dois valores <i>O<sub>j</sub></i> e <i>E<sub>j</sub></i> coincidam perfeitamente para qualquer número finito de medidas que realizarmos. Na verdade, se imaginarmos uma situação onde realizamos o procedimento de contar o número Oj muitas vezes, esperamos que a média de <i>O<sub>j</sub></i> seja <i>E<sub>j</sub></i>, com um desvio padrão <i>σ<sub>j</sub>=E<sub>j</sub><sup>1/2</sup></i>. Logo, esperamos que</p>

# %%
#######################################################################################################################
## esse código LaTex é apenas para escrever a fórmula direitinho para vocês
print('Fórmula: ')
display(Math(r'{\frac  {O_{j}-E_{j}}{\sigma _{j}}}'))
#######################################################################################################################
# Out:
# Fórmula:
# $\displaystyle {\frac  {O_{j}-E_{j}}{\sigma _{j}}}$

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">seja da ordem de unidade, se nossa hipótese for verdadeira. Definimos, portanto, a variável <i>X<sub>k</sub>²</i>, com k graus de liberdade estatísticos, como sendo</p>

# %%
#######################################################################################################################
## esse código LaTex é apenas para escrever a fórmula direitinho para vocês
print('Fórmula: ')
display(Math(r'\chi _{k}^{2}\equiv \sum _{{j=1}}^{n}{\frac  {(O_{j}-E_{j})^{2}}{E_{j}}}'))
#######################################################################################################################
# Out:
# Fórmula:
# $\displaystyle \chi _{k}^{2}\equiv \sum _{{j=1}}^{n}{\frac  {(O_{j}-E_{j})^{2}}{E_{j}}}$

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;"> indicando o quanto as distribuições experimental e teórica são parecidas. Se <i>X <sup>2</sup> ≤ n</i>, há uma boa concordância entre as distribuições, e se <i>X <sup>2</sup> >> n</i> é bem provável que a hipótese para <i>f(X)</i> seja falsa. Os graus de liberdade k são definidos como a diferença entre o número de medidas realizadas e o número de restrições feitas aos valores das medidas.</p>
# <p style="text-align:justify;text-justify:inter-word;">É possível estudar as discrepâncias em experimentos que envolvam duas variáveis, em diferentes níveis. Os valores observados podem ser anotados em um quadro da seguinte forma:</p>
# <p style="text-align:center;text-justify:inter-word;"><img src="./qui-quadrado.png" alt="qui-quadrado"></p>
# <p style="text-align:justify;text-justify:inter-word;">O objetivo é observar o nível de relação existente entre as variáveis estudadas. Nesse caso, a estatística de teste é dada por:</p>

# %%
#######################################################################################################################
## esse código LaTex é apenas para escrever a fórmula direitinho para vocês
print('Fórmula: ')
display(Math(r'{\chi _{k}^{2}\equiv \sum _{i=1}^{m}\sum _{j=1}^{n}{\frac {(O_{ij}-E_{ij})^{2}}{E_{ij}}}}'))
#######################################################################################################################
# Out:
# Fórmula:
# $\displaystyle {\chi _{k}^{2}\equiv \sum _{i=1}^{m}\sum _{j=1}^{n}{\frac {(O_{ij}-E_{ij})^{2}}{E_{ij}}}}$

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">onde as frequências esperadas são dadas por:</p>

# %%
#######################################################################################################################
## esse código LaTex é apenas para escrever a fórmula direitinho para vocês
print('Fórmula: ')
display(Math(r'{E_{ij}={\frac {L_{i}C_{j}}{T}}}'))
#######################################################################################################################
# Out:
# Fórmula:
# $\displaystyle {E_{ij}={\frac {L_{i}C_{j}}{T}}}$

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">Aplicando aos dados:</p>

# %%
##importando a estatistica x²
from sklearn.feature_selection import chi2

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">Calculando o x² para os atributos</p>
# <ul>
#     <li>O primeiro array faz referencia ao F-score</li>
#     <li>O segundo array trata-se do P-value</li>
# </ul>

# %%
f_score=chi2(X_train.fillna(0),y_train)
f_score
# Out:
# (array([  6.20574548,  12.73401295,  29.14728153,  38.51075713,
#          39.54212512, 124.67939584,  40.08079133,  90.72659542,
#          89.2022745 ,  60.93443749,   3.16064089, 108.24320374,
#           4.41112897,  41.96915577, 102.14263851,  72.17787863,
#           3.62912917,  10.53616262,  25.54481251, 122.04519791,
#         119.29789424, 116.62809917,  24.80278006,  42.98159081,
#         104.25860547,  38.09534731, 130.00287316,  75.23786909,
#         127.8974178 ,  24.96442088,  35.10707312,   4.64726884,
#         168.7841839 ,   8.13669766]),
#  array([2.86710716e-01, 2.60030302e-02, 2.16947791e-05, 2.97893082e-07,
#         1.84697156e-07, 3.19986279e-25, 1.43838029e-07, 4.72792560e-18,
#         9.88273787e-18, 7.79056845e-12, 6.75235452e-01, 9.63134154e-22,
#         4.91861391e-01, 5.97567123e-08, 1.86779507e-20, 3.60678768e-14,
#         6.03945052e-01, 6.13928597e-02, 1.09328195e-04, 1.15731839e-24,
# ...

# %%
#listando os p-values por variável
p_values = pd.Series(f_score[1])
p_values.index=X_train.columns
pv = p_values.sort_values(ascending = False)
pv
# Out:
# family history                              6.752355e-01
# acanthosis                                  6.039451e-01
# eosinophils in the infiltrate               4.918614e-01
# inflammatory monoluclear inflitrate         4.604243e-01
# erythema                                    2.867107e-01
# age                                         1.488611e-01
# hyperkeratosis                              6.139286e-02
# scaling                                     2.600303e-02
# spongiform pustule                          1.520965e-04
# follicular horn plug                        1.415551e-04
# parakeratosis                               1.093282e-04
# definite borders                            2.169478e-05
# perifollicular parakeratosis                1.432402e-06
# disappearance of the granular layer         3.610431e-07
# itching                                     2.978931e-07
# koebner phenomenon                          1.846972e-07
# ...

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">Diferentemente do Mutual Information, quanto menor o valor de <i>p-value</i>, melhor o atributo define o <i>target</i>.

# %%
pv.plot.bar(figsize=(15,7))

# %% [markdown]
# <h3>ANÁLISE EXPLORATÓRIA DOS DADOS NO DATAFRAME COM DADOS CLÍNICOS</h3>

# %%
##Observação dos dados clinicos
df_clinico
# Out:
#      erythema  scaling  definite borders  itching  koebner phenomenon  \
# 0           3        3                 1        4                   1
# 1           4        4                 4        3                   2
# 2           3        2                 3        4                   2
# 3           3        3                 3        1                   1
# 4           3        4                 3        3                   3
# ..        ...      ...               ...      ...                 ...
# 361         3        2                 2        1                   2
# 362         4        3                 2        1                   2
# 363         4        3                 3        3                   4
# 364         3        2                 4        2                   3
# 365         4        3                 3        1                   1
#
#      polygonal papules  follicular papules  oral mucosal involvement  \
# ...

# %%
##separando os conjuntos de treinamento e teste
X_train_clinico, X_test_clinico, y_train_clinico, y_test_clinico = train_test_split(df_clinico.drop(['target'],axis=1),df_clinico['target'], test_size=0.4, random_state=0)
## mostrando os conjuntos de treinamento e teste
print('Dados de Treino {}'.format(X_train_clinico.shape))
print('Target de Treino {}'.format(y_train_clinico.shape))
print("Dados de Teste {}".format(X_test_clinico.shape))
print('Target de Teste {}'.format(y_test_clinico.shape))
# Out:
# Dados de Treino (219, 12)
# Target de Treino (219,)
# Dados de Teste (147, 12)
# Target de Teste (147,)

# %%
##Mutual information
mi_clinico = mutual_info_classif(X_train_clinico.fillna(0), y_train_clinico)
mi_clinico = pd.Series(mi_clinico)
mi_clinico
mi_clinico.index = X_train_clinico.columns
mi_clinico = mi_clinico.sort_values(ascending = False)
mi_clinico.plot.bar(figsize=(15,7))

# %%
##Qui_quadrado
f_score_clinico=chi2(X_train_clinico.fillna(0),y_train_clinico)
f_score_clinico
#listando os p-values por variável
p_values_clinico = pd.Series(f_score_clinico[1])
p_values_clinico.index=X_train_clinico.columns
pv_clinico = p_values_clinico.sort_values(ascending = False)
pv_clinico
# Out:
# family history                6.752355e-01
# erythema                      2.867107e-01
# age                           1.488611e-01
# scaling                       2.600303e-02
# definite borders              2.169478e-05
# itching                       2.978931e-07
# koebner phenomenon            1.846972e-07
# follicular papules            1.438380e-07
# scalp involvement             7.790568e-12
# knee and elbow involvement    9.882738e-18
# oral mucosal involvement      4.727926e-18
# polygonal papules             3.199863e-25
# dtype: float64

# %%
pv_clinico.plot.bar(figsize=(15,7))

# %% [markdown]
# <div style="color: rgb(255,255,255); background-color: rgb(150,0,0); width: 700px; height: 115px; text-align: Justify; padding: 10px;">
#     <br><strong>*** NOTA:</strong> Apenas lembrando que na técnica <i>Mutual Information</i> quanto menor o valor, menos a variável descreve a relação com o <i>target</i>. Já no Teste Qui-Quadrado quanto menor o valor, mais a variável descreve a relação com o <i>target</i>.
# </div>

# %% [markdown]
# <h4>ANÁLISE DE COMPONENTES PRINCIPAIS</h4>
# <p style="text-align:justify;text-justify:inter-word;">Observando os gráficos acima, nota-se que os atributos <i>age</i> (idade), <i>scaling</i> (tamanho da lesão), <i>itching</i> (coceira), <i>family history</i> (histórico familiar) e <i>erythema</i> (eritema) tiveram baixa relevância em relação ao <i>target</i> em ambas as técnicas.</p>
# <p style="text-align:justify;text-justify:inter-word;">Este, portanto, poderia ser o critério de seleção das variáveis para testar a classificação. As variáveis supracitadas poderiam ser retiradas desse modelo, porém, sabe-se que há nelas alguma informação. Para fazer a redução de variáveis é aplicada uma análise fatorial.</p>
# <p style="text-align:justify;text-justify:inter-word;"> A Análise de Componentes Principais (em inglês PCA) é o nome comum dado à técnica que usa princípios de álgebra linear para transformar variáveis, possivelmente correlacionadas, em um número menor de variáveis chamadas de Componentes Principais (novamente em inglês PC).</p>
# <p style="text-align:justify;text-justify:inter-word;"> A PCA é usada em diversas aplicações, desde a compressão de dados até remoção de ruídos, passando pela análises de grande quantidade de dados.</p>
# <p style="text-align:justify;text-justify:inter-word;">Com a PCA pode-se reduzir a quantidade de variáveis sem perder as informações. Portanto, torna-se melhor do que simplesmente excluir as variáveis. </p>

# %%
#vamos reduzir de 12 para  8 variáveis 
from sklearn.decomposition import PCA
X_clinico = np.array(df_clinico.drop('target',1))
y_clinico = np.array(df_clinico.target)
pca_c = PCA(n_components = 8)
pca_c.fit(X_clinico,y_clinico)
X_clinico  = pca_c.transform(X_clinico)
#index da lista
cols_clinico = list(['x1','x2','x3','x4','x5','x6','x7','x8'])

#unindo pca clinico com com o target
df_clinico_pca = pd.DataFrame(X_clinico,columns=cols_clinico)
df_clinico_pca.insert(8,'target',y_clinico) 
df_clinico_pca

#print(pca.explained_variance_ratio_)
#print(pca)
# Out:
#            x1        x2        x3        x4        x5        x6        x7  \
# 0    0.286151 -1.174734  1.760701 -0.540156 -0.467755 -0.524759  0.443569
# 1   -0.510110  1.537562  0.709537  0.947792 -1.086691  1.347449 -0.736293
# 2    3.727871  0.884097 -0.352404  1.077977  0.034376 -1.123618  0.420962
# 3   -2.600331  1.524513 -0.032748  0.379169  0.426423 -0.858806  0.143068
# 4    2.467900  1.302054 -0.609040 -0.353673 -0.098910  0.404936  0.481538
# ..        ...       ...       ...       ...       ...       ...       ...
# 361 -0.496416 -1.145076 -1.071579 -0.133561  0.785625  0.657868  0.098467
# 362 -0.649199 -0.698024 -1.042896 -0.123080 -0.140704  1.315012  0.685985
# 363  2.720154  1.434377 -0.569618  0.426940  0.535128  1.406801  0.737630
# 364  2.696548  1.595623 -1.990443 -0.162225  0.788149 -0.408067  0.003663
# 365 -2.943652  2.124338  0.305612  0.320615  0.106333 -0.649675  0.890565
#
#            x8  target
# 0    0.939830       2
# 1   -0.169585       1
# ...

# %%
##plotando a dispersão (grau de espalhamento dos dados) 
sb.pairplot(df_clinico_pca, hue="target")

# %%
#separando os dados de classificação para dados clinicos
##excluindo os dados: "family history","scaling","erythema", "age"
att_sel = list(df_clinico.columns)
att_sel.remove('age')
att_sel.remove('erythema')
att_sel.remove('scaling')
att_sel.remove('family history')
df_clinico_cut = df_clinico[att_sel]
df_clinico_cut
# Out:
#      definite borders  itching  koebner phenomenon  polygonal papules  \
# 0                   1        4                   1                  1
# 1                   4        3                   2                  1
# 2                   3        4                   2                  4
# 3                   3        1                   1                  1
# 4                   3        3                   3                  3
# ..                ...      ...                 ...                ...
# 361                 2        1                   2                  1
# 362                 2        1                   2                  1
# 363                 3        3                   4                  3
# 364                 4        2                   3                  4
# 365                 3        1                   1                  1
#
#      follicular papules  oral mucosal involvement  knee and elbow involvement  \
# ...

# %%
#gravando o conjunto de dados clinicos já tratados
df_clinico.to_csv('dermatology_clinico.csv')
df_clinico_cut.to_csv('dermatology_clinico_cut.csv')
df_clinico_pca.to_csv('dermatologogy_clinico_pca.csv')

# %% [markdown]
# <div style="color: rgb(255,255,255); background-color: rgb(150,0,0); width: 780px; height: 170px; text-align: Justify; padding: 10px;">
#     <br><strong>*** NOTA:</strong> Agora tem-se mais três <i>dataframes</i>, além do original e o dos 10 melhores atributos, para testar e comparar quanto a eficiência na classificação.
#     <ul>
#         <li>dermatology_clinico.csv (dados clinicos originais)</il>
#         <li>dermatology_clinico_cut.csv (dados de menor significância foram removidos)</il>
#         <li>dermatology_clinico_pca.csv (aplicação da PCA)</il>
#     </ul>
# </div>

# %% [markdown]
# <h3>ANÁLISE EXPLORATÓRIA DOS DADOS NO DATAFRAME COM DADOS HISTOPATOLÓGICOS</h3>
# <p style="text-align:justify;text-justify:inter-word;">Repete-se os mesmos procedimentos realizados com os dados clínicos, aplicando-os aos dados histopatológicos. </p>

# %%
df_histopatologico
# Out:
#      melanin incontinence  eosinophils in the infiltrate  PNL infiltrate  \
# 0                       1                              1               1
# 1                       1                              1               2
# 2                       2                              1               1
# 3                       1                              1               4
# 4                       2                              1               1
# ..                    ...                            ...             ...
# 361                     1                              1               2
# 362                     1                              1               1
# 363                     3                              3               1
# 364                     3                              1               1
# 365                     1                              1               2
#
#      fibrosis of the papillary dermis  exocytosis  acanthosis  hyperkeratosis  \
# ...

# %%
##separando os conjuntos de treinamento e teste
X_train_histopatologico, X_test_histopatologico, y_train_histopatologico, y_test_histopatologico = train_test_split(df_histopatologico.drop(['target'],axis=1),df_histopatologico['target'], test_size=0.4, random_state=0)
## mostrando os conjuntos de treinamento e teste
print('Dados de Treino {}'.format(X_train_histopatologico.shape))
print('Target de Treino {}'.format(y_train_histopatologico.shape))
print("Dados de Teste {}".format(X_test_histopatologico.shape))
print('Target de Teste {}'.format(y_test_histopatologico.shape))
# Out:
# Dados de Treino (219, 22)
# Target de Treino (219,)
# Dados de Teste (147, 22)
# Target de Teste (147,)

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">Observa-se 22 atributos histopatológicos. Portanto, deve-se investigar quais desses atributos são realmente significativos.</p>

# %%
##Mutual information
mi_histopatologico = mutual_info_classif(X_train_histopatologico.fillna(0), y_train_histopatologico)
mi_histopatologico = pd.Series(mi_histopatologico)
mi_histopatologico
mi_histopatologico.index = X_train_histopatologico.columns
mi_histopatologico = mi_histopatologico.sort_values(ascending = False)
mi_histopatologico.plot.bar(figsize=(15,7))

# %%
##Qui_quadrado
f_score_histopatologico=chi2(X_train_histopatologico.fillna(0),y_train_histopatologico)
f_score_histopatologico
#listando os p-values por variável
p_values_histopatologico = pd.Series(f_score_histopatologico[1])
p_values_histopatologico.index=X_train_histopatologico.columns
pv_histopatologico = p_values_histopatologico.sort_values(ascending = False)
pv_histopatologico
# Out:
# acanthosis                                  6.039451e-01
# eosinophils in the infiltrate               4.918614e-01
# inflammatory monoluclear inflitrate         4.604243e-01
# hyperkeratosis                              6.139286e-02
# spongiform pustule                          1.520965e-04
# follicular horn plug                        1.415551e-04
# parakeratosis                               1.093282e-04
# perifollicular parakeratosis                1.432402e-06
# disappearance of the granular layer         3.610431e-07
# PNL infiltrate                              5.975671e-08
# munro microabcess                           3.726959e-08
# exocytosis                                  3.606788e-14
# spongiosis                                  8.298065e-15
# fibrosis of the papillary dermis            1.867795e-20
# focal hypergranulosis                       6.682728e-21
# melanin incontinence                        9.631342e-22
# ...

# %%
pv_histopatologico.plot.bar(figsize=(15,7))

# %% [markdown]
# <p style="text-align:justify;text-justify:inter-word;">Observa-se que os atributos abaixo possuem baixa relevância para a classificação:</p>
# <ul>
#     <li>acanthosis</li>
#     <li>eosinophils in the infiltrate</li>
#     <li>inflammatory monoluclear inflitrate</li>
#     <li>hyperkeratosis</li>
#     <li>spongiform pustule</li>
#     <li>follicular horn plug</li>
#     <li>parakeratosis</li>
#     <li>perifollicular parakeratosis</li>
#     <li>disappearance of the granular layer</li>
# </ul>

# %%
#PCA nos dados histopatológicos
X_histopatologico = np.array(df_histopatologico.drop('target',1))
y_histopatologico = np.array(df_histopatologico.target)
pca_h = PCA(n_components = 13)
pca_h.fit(X_histopatologico,y_histopatologico)
X_histopatologico  = pca_h.transform(X_histopatologico)
#index da lista
cols_histopatologico = list(['x1','x2','x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13'])

#unindo pca clinico com com o target
df_histopatologico_pca = pd.DataFrame(X_histopatologico,columns=cols_histopatologico)
df_histopatologico_pca.insert(13,'target',y_histopatologico) 
df_histopatologico_pca
# Out:
#            x1        x2        x3        x4        x5        x6        x7  \
# 0    1.649016 -2.637610 -0.914987 -0.562166 -0.228511 -0.476960 -0.066696
# 1   -2.623815  0.730716 -0.527318  0.463838 -0.050605  1.025641 -0.024979
# 2    3.453349  1.636429 -0.667849 -0.786217  0.829583  0.255644 -1.207398
# 3   -3.607450  1.644628 -1.666203 -0.702197 -1.082975  1.375946 -0.209175
# 4    3.742081  2.520044 -0.117331 -0.558804 -1.323772 -0.850027 -1.174329
# ..        ...       ...       ...       ...       ...       ...       ...
# 361  0.455341 -1.739157 -0.045649  0.823118 -1.298269  0.241866 -0.239238
# 362  0.743323 -1.601427 -0.061313 -0.052117 -1.179230 -0.793884 -0.084097
# 363  4.782440  3.178330  0.790776  0.250299 -0.745641  0.447644  0.453300
# 364  3.953792  2.098655  0.650442  0.717521 -1.068207 -0.033544  0.462259
# 365 -3.760726  1.922943 -1.012905 -0.643393 -0.830646 -1.059764 -0.011417
#
#            x8        x9       x10       x11       x12       x13  target
# ...

# %%
##separando os dados de classificação para dados histopatológicos
##excluindo os dados:
#acanthosis
#eosinophils in the infiltrate
#inflammatory monoluclear inflitrate
#hyperkeratosis
#spongiform pustule
#follicular horn plug
#parakeratosis
#perifollicular parakeratosis
#disappearance of the granular layer

att_sel = list(df_histopatologico.columns)
att_sel.remove('acanthosis')
att_sel.remove('eosinophils in the infiltrate')
att_sel.remove('inflammatory monoluclear inflitrate')
att_sel.remove('hyperkeratosis')
att_sel.remove('spongiform pustule')
att_sel.remove('follicular horn plug')
att_sel.remove('parakeratosis')
att_sel.remove('perifollicular parakeratosis')
att_sel.remove('disappearance of the granular layer')

df_histopatologico_cut = df_histopatologico[att_sel]
df_histopatologico_cut
# Out:
#      melanin incontinence  PNL infiltrate  fibrosis of the papillary dermis  \
# 0                       1               1                                 1
# 1                       1               2                                 1
# 2                       2               1                                 1
# 3                       1               4                                 1
# 4                       2               1                                 1
# ..                    ...             ...                               ...
# 361                     1               2                                 1
# 362                     1               1                                 1
# 363                     3               1                                 1
# 364                     3               1                                 1
# 365                     1               2                                 1
#
# ...

# %%
##plotando a dispersão (grau de espalhamento dos dados) 
sb.pairplot(df_histopatologico_pca, hue="target")

# %%
#gravando o conjunto de dados histopatologicos já tratados
df_histopatologico.to_csv('dermatology_histopatologico.csv')
df_histopatologico_cut.to_csv('dermatology_histopatologico_cut.csv')
df_histopatologico_pca.to_csv('dermatologogy_histopatologico_pca.csv')

# %% [markdown]
# <div style="color: rgb(255,255,255); background-color: rgb(150,0,0); width: 780px; height: 150px; text-align: Justify; padding: 10px;">
#     <br><strong>*** NOTA:</strong> Agora tem-se mais três <i>dataframes</i>.
#     <ul>
#         <li>dermatology_histopatologico.csv (dados histopatologicos originais)</li>
#         <li>dermatology_histopatologico_cut.csv (dados de menor significância foram removidos</li>
#         <li>dermatology_histopatologico_pca.csv (aplicação da PCA)</li>
#     </ul>
# </div>

# %% [markdown]
# <h2>CONCLUSÃO DA PRIMEIRA ETAPA DO EXPERIMENTO</h2>
# <p style="text-align:justify;text-justify:inter-word;">Após algumas análises e processamento dos dados, tem-se 8 <i>dataframes</i> (incluindo o original) para testar as classificações.</p>
# <p style="text-align:justify;text-justify:inter-word;">Para que este ensaio não fique muito pesado em uma folha apenas, opta-se por subdividi-lo por meio de outros <i>noteboks</i>, cujos links podem ser acessados abaixo:</p>
# <ol>
#     <li>Testes de classificação com KNN</li>
# </ol>
